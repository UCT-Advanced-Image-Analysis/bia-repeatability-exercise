# %%
# !pip install -r requirements.txt

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('counting_table.csv', sep=";")
data.head()
# Out:
#      github_tag   manual_count   manual_threshold_count   script_count
# 0       schatzm             54                       65             61
# 1       seinerj             53                       65             60
# 2      josifkoh             62                       64             61
# 3        cilerj             54                       60             61
# 4  sebestikovaa             65                       63             60

# %%
# data_melt.head()

# %%
figure = plt.subplots(figsize=(8, 6))

# sns.violinplot(data, x="class", y="age", hue="alive")
sns.violinplot(data).set(title="Comparison Results")
# Out:
# [Text(0.5, 1.0, 'Comparison Results')]

# %%
figure.savefig('comparison_plot.png', dpi=400)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 figure.savefig('comparison_plot.png', dpi=400)
#
# AttributeError: 'tuple' object has no attribute 'savefig'
